# %%
# !python main.py --dataset 'hynix' --augment_mirror True --augment_translation 2 --n_labeled 2071 --lr_max 0.003 --ratio_max 300.0 -e 100 --random_seed 99
# Out:
# PY 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
# TF 1.14.0
# Random seed: 99
# (32, 32, 3)
# [11 12  8 ... 13 12 21]
# -0.006348335648787995
#
#
# [*] Start optimization
#
# Total # of params: 3123372
#
#
# Epoch 000 / 100
#
# (100, 32, 32, 3)
# [*] total loss:2.8816e+00 | sup loss: 2.8816e+00 | perturbation-loss:0.0000e+00 | graph-loss:0.0000e+00
# [*] lr: 0.0000202 | beta1: 0.900000 | ratio: 0.000000 | time: 11.084018
# [*] TRAIN Top-1 CNN Acc: 0.2320
# [*] Pos: 17.533925, NEG: 1076.161724, N_hard: 125.000000
# [*] TEST  Top-1 CNN Acc: 0.0620
#
#
# Epoch 001 / 100
#
# [*] total loss:2.1563e+00 | sup loss: 2.1484e+00 | perturbation-loss:7.9791e-03 | graph-loss:0.0000e+00
# [*] lr: 0.0000281 | beta1: 0.900000 | ratio: 2.805440 | time: 20.756132
# [*] TRAIN Top-1 CNN Acc: 0.4400
# [*] Pos: 14.908206, NEG: 1049.356198, N_hard: 132.000000
# [*] TEST  Top-1 CNN Acc: 0.0200
#
#
# Epoch 002 / 100
#
# ...

# %%
# !python main.py --dataset 'hynix' --augment_mirror True --augment_translation 2 --n_labeled 2071 --lr_max 0.003 --ratio_max 300.0 -e 100 --random_seed 0 --batch_size 10
# Out:
# PY 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
# TF 1.14.0
# Random seed: 0
# (32, 32, 3)
# [0 0 0 ... 0 0 0]
# -0.0003333124470482558
#
#
# [*] Start optimization
#
# Total # of params: 3123372
#
#
# Epoch 000 / 100
#
# (10, 32, 32, 3)
# [*] total loss:3.4573e-02 | sup loss: 3.4573e-02 | perturbation-loss:0.0000e+00 | graph-loss:0.0000e+00
# [*] lr: 0.0000202 | beta1: 0.900000 | ratio: 0.000000 | time: 548.400507
# [*] TRAIN Top-1 CNN Acc: 0.0119
# [*] Pos: 593.008253, NEG: 49487.287102, N_hard: 6215.000000
# [*] TEST  Top-1 CNN Acc: 0.5000
#
#
# Epoch 001 / 100
#
# [*] total loss:2.3653e-02 | sup loss: 2.3401e-02 | perturbation-loss:2.4704e-04 | graph-loss:0.0000e+00
# [*] lr: 0.0000281 | beta1: 0.900000 | ratio: 0.053828 | time: 1097.968599
# [*] TRAIN Top-1 CNN Acc: 0.0140
# [*] Pos: 1272.504815, NEG: 35075.703752, N_hard: 7866.000000
# [*] TEST  Top-1 CNN Acc: 0.5880
#
#
# Epoch 002 / 100
#
# ...

# %%
# !python main.py --dataset 'hynix' --augment_mirror True --augment_translation 2 --n_labeled 2071 --lr_max 0.003 --ratio_max 300.0 -e 100 --random_seed 0 --batch_size 1

# %%
# !python main.py --dataset 'hynix' --augment_mirror True --augment_translation 2 --n_labeled 2071 --lr_max 0.003 --ratio_max 300.0 -e 100 --random_seed 0 --batch_size 50
